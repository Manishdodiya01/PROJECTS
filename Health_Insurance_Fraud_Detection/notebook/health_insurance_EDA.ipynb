# %%
import pandas as pd
df = pd.read_excel('Worksheet in Case Study question 2.xlsx')
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   datetime64[ns]
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.shape
# Out:
# (1000, 39)

# %%
df.isnull().sum()
# Out:
# months_as_customer              0
# age                             0
# policy_number                   0
# policy_bind_date                0
# policy_state                    0
# policy_csl                      0
# policy_deductable               0
# policy_annual_premium           0
# umbrella_limit                  0
# insured_zip                     0
# insured_sex                     0
# insured_education_level         0
# insured_occupation              0
# insured_hobbies                 0
# insured_relationship            0
# capital-gains                   0
# capital-loss                    0
# incident_date                   0
# incident_type                   0
# collision_type                  0
# incident_severity               0
# authorities_contacted          91
# incident_state                  0
# incident_city                   0
# incident_location               0
# incident_hour_of_the_day        0
# number_of_vehicles_involved     0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                               count                           mean  \
# months_as_customer           1000.0                        203.954
# age                          1000.0                         38.948
# policy_number                1000.0                     546238.648
# policy_bind_date               1000  2002-02-08 04:40:47.999999872
# policy_deductable            1000.0                         1136.0
# policy_annual_premium        1000.0                     1256.40615
# umbrella_limit               1000.0                      1101000.0
# insured_zip                  1000.0                     501214.488
# capital-gains                1000.0                        25126.1
# capital-loss                 1000.0                       -26793.7
# incident_date                  1000            2015-01-30 08:02:24
# incident_hour_of_the_day     1000.0                         11.644
# number_of_vehicles_involved  1000.0                          1.839
# ...

# %%
data = ['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
       'policy_state', 'policy_csl', 'policy_deductable',
       'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
       'insured_education_level', 'insured_occupation', 'insured_hobbies',
       'insured_relationship', 'capital-gains', 'capital-loss',
       'incident_date', 'incident_type', 'collision_type', 'incident_severity',
       'authorities_contacted', 'incident_state', 'incident_city',
       'incident_location', 'incident_hour_of_the_day',
       'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
       'witnesses', 'police_report_available', 'total_claim_amount',
       'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
       'auto_model', 'auto_year', 'fraud_reported']

numerical_data = df.select_dtypes(include='number')
categorical_data = df.select_dtypes(include="O")
categorical_data_two = categorical_data.drop('incident_location' , axis=1)

# %%
numerical_features = df.select_dtypes(include='number').columns.tolist()
numerical_features
# Out:
# ['months_as_customer',
#  'age',
#  'policy_number',
#  'policy_deductable',
#  'policy_annual_premium',
#  'umbrella_limit',
#  'insured_zip',
#  'capital-gains',
#  'capital-loss',
#  'incident_hour_of_the_day',
#  'number_of_vehicles_involved',
#  'bodily_injuries',
#  'witnesses',
#  'total_claim_amount',
#  'injury_claim',
#  'property_claim',
#  'vehicle_claim',
#  'auto_year']

# %%
values = {}
for i in categorical_data_two:
    values[i] = df[i].unique()

# %%
for name , value in values.items():
    print("COLUMN-NAME:",name)
    print("COLUMN-UNIQUE-VALUE:",value)
    print('*'*50)
# Out:
# COLUMN-NAME: policy_state
# COLUMN-UNIQUE-VALUE: ['OH' 'IN' 'IL']
# **************************************************
# COLUMN-NAME: policy_csl
# COLUMN-UNIQUE-VALUE: ['250/500' '100/300' '500/1000']
# **************************************************
# COLUMN-NAME: insured_sex
# COLUMN-UNIQUE-VALUE: ['MALE' 'FEMALE']
# **************************************************
# COLUMN-NAME: insured_education_level
# COLUMN-UNIQUE-VALUE: ['MD' 'PhD' 'Associate' 'Masters' 'High School' 'College' 'JD']
# **************************************************
# COLUMN-NAME: insured_occupation
# COLUMN-UNIQUE-VALUE: ['craft-repair' 'machine-op-inspct' 'sales' 'armed-forces' 'tech-support'
#  'prof-specialty' 'other-service' 'priv-house-serv' 'exec-managerial'
#  'protective-serv' 'transport-moving' 'handlers-cleaners' 'adm-clerical'
#  'farming-fishing']
# **************************************************
# COLUMN-NAME: insured_hobbies
# ...

# %%
value_counts = {}
for i in categorical_data_two:
    value_counts[i] = df[i].value_counts()

# %%
for name , value in categorical_data_two.items():
    print('COLUMN-NAME : ',name)
    print('COLUMN-VALUE-COUNT : ',value)
    print("*"*50)
# Out:
# COLUMN-NAME :  policy_state
# COLUMN-VALUE-COUNT :  0      OH
# 1      IN
# 2      OH
# 3      IL
# 4      IL
#        ..
# 995    OH
# 996    IL
# 997    OH
# 998    IL
# 999    OH
# Name: policy_state, Length: 1000, dtype: object
# **************************************************
# COLUMN-NAME :  policy_csl
# COLUMN-VALUE-COUNT :  0       250/500
# 1       250/500
# 2       100/300
# 3       250/500
# 4      500/1000
#          ...
# 995    500/1000
# 996     100/300
# 997     250/500
# 998    500/1000
# 999     250/500
# Name: policy_csl, Length: 1000, dtype: object
# **************************************************
# COLUMN-NAME :  insured_sex
# COLUMN-VALUE-COUNT :  0        MALE
# 1        MALE
# 2      FEMALE
# 3      FEMALE
# 4        MALE
#         ...
# 995    FEMALE
# 996    FEMALE
# 997    FEMALE
# 998      MALE
# 999    FEMALE
# Name: insured_sex, Length: 1000, dtype: object
# **************************************************
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
# Use: To visualize the distribution of a single numerical variable.

sns.histplot(df['total_claim_amount'])
plt.show()
# Out:
# C:\Users\dodiy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Use: To compare the frequency or distribution of categorical variables.

sns.barplot(x=df['policy_state'],y=df['total_claim_amount'])
plt.show()

# %%
# Purpose: Tracking trends over time (continuous variable). Useful for spotting seasonal patterns in fraud reports or claim amounts over months_as_customer.


sns.lineplot(x=df['months_as_customer'] , y=df['total_claim_amount'])
plt.show()
# Out:
# C:\Users\dodiy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dodiy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df['months_as_customer'].describe()
# Out:
# count    1000.000000
# mean      203.954000
# std       115.113174
# min         0.000000
# 25%       115.750000
# 50%       199.500000
# 75%       276.250000
# max       479.000000
# Name: months_as_customer, dtype: float64

# %%
sns.lineplot(x=df['policy_bind_date'],y=df['total_claim_amount'])
# Out:
# C:\Users\dodiy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dodiy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='policy_bind_date', ylabel='total_claim_amount'>

# %%
sns.lineplot(x=df['months_as_customer'] ,y=df['age'])
# Out:
# C:\Users\dodiy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dodiy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='months_as_customer', ylabel='age'>

# %%
# Purpose: Exploring relationships between numerical variables. 
# Can be used to investigate potential correlations between capital-gains and total_claim_amount (be cautious of interpreting causation).
# X-axis: One numerical variable (e.g., capital-gains).
# Y-axis: Another numerical variable (e.g., total_claim_amount).

sns.scatterplot(x=df['capital-gains'] , y=df['total_claim_amount'])
plt.show()

# %%
sns.scatterplot(x=df['total_claim_amount'] , y=df['vehicle_claim'])
plt.show()

# %%
# The relationship between 'total_claim_amount' and 'vehicle_claim' could indicate how one variable changes as the other variable changes.
# For example, if there's a positive correlation, it means that as 'total_claim_amount' increases, 'vehicle_claim' also tends to increase.
# Conversely, if there's a negative correlation, it means that as 'total_claim_amount' increases, 'vehicle_claim' tends to decrease.

# %%
# Use: To show the proportion of different categories within a dataset.

data = df['insured_sex'].value_counts()
plt.pie(x=data.values , labels=data.index , colors=['r','b'])
plt.legend()
plt.show()

# %%
# Use: To visualize the distribution of numerical data across different categories.
# X-axis: Categorical variable (e.g., policy_state, incident_type)
# Y-axis: Numerical variable (e.g., total_claim_amount)
sns.violinplot(x=df['incident_type'] , y=df['total_claim_amount'])
plt.xticks(rotation=45)
plt.show()

# %%
# The violin plot will display the distribution of 'total_claim_amount' for each category of 'incident_type'.
# This can help you understand how the total claim amounts are distributed across different types of incidents.

# %%
# Selecting numerical columns
numeric_df = df.select_dtypes(include='number')

# Calculating correlation matrix
corr = numeric_df.corr()

# Creating heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Numerical Columns")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

# %%
df['fraud_reported'].value_counts()
# Out:
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64

# %%
fraud_mapping = {
    "N" : 0,
    "Y" : 1
}

target_maped = df['fraud_reported'].map(fraud_mapping)

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
grouped = df.groupby(['policy_state', 'incident_type'])['total_claim_amount'].mean()

# %%
grouped.reset_index()
# Out:
#    policy_state             incident_type  total_claim_amount
# 0            IL   Multi-vehicle Collision        61685.359477
# 1            IL                Parked Car         4873.600000
# 2            IL  Single Vehicle Collision        63960.944882
# 3            IL             Vehicle Theft         5411.818182
# 4            IN   Multi-vehicle Collision        61293.658537
# 5            IN                Parked Car         5663.548387
# 6            IN  Single Vehicle Collision        66822.343750
# 7            IN             Vehicle Theft         5864.642857
# 8            OH   Multi-vehicle Collision        61880.629371
# 9            OH                Parked Car         5302.857143
# 10           OH  Single Vehicle Collision        62805.540541
# 11           OH             Vehicle Theft         5327.878788

# %%
grouped_m = df.groupby(['policy_state', 'incident_type', 'fraud_reported']).agg({
    'months_as_customer': 'mean',
    'age': 'mean',
    'total_claim_amount': ['mean', 'sum'],
    # You can add more numerical columns here
})

# %%
grouped_m.reset_index()
# Out:
#    policy_state             incident_type fraud_reported months_as_customer  \
#                                                                        mean
# 0            IL   Multi-vehicle Collision              N         203.137931
# 1            IL   Multi-vehicle Collision              Y         220.972973
# 2            IL                Parked Car              N         188.090909
# 3            IL                Parked Car              Y         242.000000
# 4            IL  Single Vehicle Collision              N         207.301075
# 5            IL  Single Vehicle Collision              Y         178.205882
# 6            IL             Vehicle Theft              N         200.166667
# 7            IL             Vehicle Theft              Y         252.666667
# 8            IN   Multi-vehicle Collision              N         215.090909
# 9            IN   Multi-vehicle Collision              Y         199.485714
# ...

# %%
import matplotlib.pyplot as plt

# Plot mean months_as_customer
grouped_m['months_as_customer']['mean'].plot(kind='bar', figsize=(10, 6))
plt.title('Mean Months as Customer by Group')
plt.xlabel('Group (Policy State, Incident Type, Fraud Reported)')
plt.ylabel('Mean Months as Customer')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Plot mean age
grouped_m['age']['mean'].plot(kind='bar', figsize=(10, 6))
plt.title('Mean Age by Group')
plt.xlabel('Group (Policy State, Incident Type, Fraud Reported)')
plt.ylabel('Mean Age')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Plot mean and sum total_claim_amount
grouped_m['total_claim_amount'].plot(kind='bar', figsize=(10, 6))
plt.title('Mean and Sum Total Claim Amount by Group')
plt.xlabel('Group (Policy State, Incident Type, Fraud Reported)')
plt.ylabel('Total Claim Amount')
plt.legend(['Mean', 'Sum'])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
fraudulent_claims = df[df['fraud_reported'] == "Y"]
number_of_fraudulent_claims = len(fraudulent_claims)
total_claims = len(df['fraud_reported'])
fraud_rate = (number_of_fraudulent_claims / total_claims) * 100
print('FRAUD-RATE :',fraud_rate)
# Out:
# FRAUD-RATE : 24.7

# %%
number_of_fraudulent_claims
# Out:
# 247

# %%
policy_state_counts = df['policy_state'].value_counts()
total_claim_amount_fraudulent = fraudulent_claims['total_claim_amount']
age_fraudulent = fraudulent_claims['age']
incident_date = df['incident_date']  
incident_type = df['incident_type']
incident_severity = df['incident_severity']
insured_education_level = df['insured_education_level']

# %%
# Pie Chart of Fraudulent vs. Non-Fraudulent Claims
plt.figure(figsize=(6, 6))
plt.pie([number_of_fraudulent_claims, total_claims - number_of_fraudulent_claims], labels=['Fraudulent', 'Non-Fraudulent'], autopct='%1.1f%%', colors=['red', 'blue'])
plt.title('Fraudulent vs. Non-Fraudulent Claims')
plt.show()

# %%
# Bar Plot of Fraud Rate by Policy State
plt.figure(figsize=(8, 6))
sns.barplot(x=policy_state_counts.index, y=(policy_state_counts / total_claims * 100))
plt.xlabel('Policy State')
plt.ylabel('Fraud Rate (%)')
plt.title('Fraud Rate by Policy State')
plt.show()

# %%
# Histogram of Total Claim Amount for Fraudulent Claims
plt.figure(figsize=(8, 6))
plt.hist(total_claim_amount_fraudulent, bins=20, color='red', alpha=0.7)
plt.xlabel('Total Claim Amount')
plt.ylabel('Frequency')
plt.title('Total Claim Amount Distribution for Fraudulent Claims')
plt.show()

# %%
# Box Plot of Age for Fraudulent Claims
plt.figure(figsize=(8, 6))
sns.boxplot(y=age_fraudulent, color='red')
plt.ylabel('Age')
plt.title('Age Distribution for Fraudulent Claims')
plt.show()

# %%
# Violin Plot of Total Claim Amount by Fraudulent vs. Non-Fraudulent Claims
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['fraud_reported'], y=df['total_claim_amount'])
plt.xlabel('Fraudulent Claims')
plt.ylabel('Total Claim Amount')
plt.title('Total Claim Amount Distribution by Fraudulent vs. Non-Fraudulent Claims')
plt.show()

# %%
# Scatter Plot of Age vs. Total Claim Amount for Fraudulent Claims
plt.figure(figsize=(8, 6))
plt.scatter(age_fraudulent, total_claim_amount_fraudulent, color='red')
plt.xlabel('Age')
plt.ylabel('Total Claim Amount')
plt.title('Age vs. Total Claim Amount for Fraudulent Claims')
plt.show()

# %%
# Stacked Bar Plot of Fraudulent Claims by Education Level
plt.figure(figsize=(8, 6))
sns.countplot(x=insured_education_level, hue=df['fraud_reported'])
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.title('Fraudulent Claims by Education Level')
plt.show()

# %%
# Heatmap of Fraud Rate by Incident Type and Severity
incident_data = df.groupby(['incident_type', 'incident_severity']).size().unstack()
incident_data = incident_data.div(incident_data.sum(axis=1), axis=0) * 100  # Convert to percentages
plt.figure(figsize=(10, 6))
sns.heatmap(incident_data, annot=True, cmap='viridis')
plt.xlabel('Incident Severity')
plt.ylabel('Incident Type')
plt.title('Fraud Rate by Incident Type and Severity')
plt.show()
# Out:
# C:\Users\dodiy\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
# Pairplot of Numerical Variables for Fraudulent Claims
sns.pairplot(df[['age', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim']][df['fraud_reported'] == "Y"])
plt.suptitle('Pairplot of Numerical Variables for Fraudulent Claims', y=1.02)
plt.show()
# Out:
# C:\Users\dodiy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dodiy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dodiy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
