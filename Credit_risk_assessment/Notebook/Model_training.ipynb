# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier , RandomForestClassifier , VotingClassifier
from sklearn.pipeline import Pipeline , make_pipeline
from sklearn.model_selection import GridSearchCV , RandomizedSearchCV , StratifiedKFold
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.preprocessing import StandardScaler , MinMaxScaler , LabelEncoder , OneHotEncoder
from sklearn.metrics import confusion_matrix , classification_report , accuracy_score , f1_score
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('credit_risk_dataset.csv')
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
duplicated_values = df.duplicated()
df[duplicated_values]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15975          23          42000                  RENT                5.0
# 15989          23          90000              MORTGAGE                7.0
# 15995          24          48000              MORTGAGE                4.0
# 16025          24          10000                  RENT                8.0
# 16028          23         100000              MORTGAGE                7.0
# ...           ...            ...                   ...                ...
# 32010          42          39996              MORTGAGE                2.0
# 32047          36         250000                  RENT                2.0
# 32172          49         120000              MORTGAGE               12.0
# 32259          39          40000                   OWN                4.0
# 32279          43          11340                  RENT                4.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 15975            VENTURE          B       6000           9.99            0
# 15989          EDUCATION          B       8000          10.36            0
# 15995            MEDICAL          A       4000           5.42            0
# 16025           PERSONAL          A       3000           7.90            1
# 16028          EDUCATION          A      15000           7.88            0
# ...                  ...        ...        ...            ...          ...
# 32010    HOMEIMPROVEMENT          A       2500           5.42            0
# 32047  DEBTCONSOLIDATION          A      20000           7.88            0
# 32172            MEDICAL          B      12000          10.99            0
# 32259            VENTURE          B       1000          10.37            0
# 32279          EDUCATION          C       1950            NaN            1
#
#        loan_percent_income cb_person_default_on_file  \
# 15975                 0.14                         N
# 15989                 0.09                         N
# 15995                 0.08                         N
# 16025                 0.30                         N
# 16028                 0.15                         N
# ...                    ...                       ...
# 32010                 0.06                         N
# 32047                 0.08                         N
# 32172                 0.10                         N
# 32259                 0.03                         N
# 32279                 0.17                         N
#
#        cb_person_cred_hist_length
# 15975                           4
# 15989                           3
# 15995                           4
# 16025                           3
# 16028                           4
# ...                           ...
# 32010                          12
# 32047                          17
# 32172                          12
# 32259                          16
# 32279                          11
#
# [165 rows x 12 columns]

# %%
df.query("person_age==23 & person_income==42000 &\
person_home_ownership=='RENT' & loan_int_rate==9.99")
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 6464           23          42000                  RENT                5.0
# 15975          23          42000                  RENT                5.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 6464      VENTURE          B       6000           9.99            0
# 15975     VENTURE          B       6000           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 6464                  0.14                         N
# 15975                 0.14                         N
#
#        cb_person_cred_hist_length
# 6464                            4
# 15975                           4

# %%
print(df.shape)
# Out:
# (32581, 12)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (32416, 12)

# %%
df['loan_status'].value_counts()
# Out:
# 0    25327
# 1     7089
# Name: loan_status, dtype: int64

# %%
# df.isna().sum() * 100 / df.shape[0]

null_value = df.isna().sum()
total_null_value = df.shape[0]

np.round(null_value * 100 / total_null_value , 2)
# Out:
# person_age                    0.00
# person_income                 0.00
# person_home_ownership         0.00
# person_emp_length             2.74
# loan_intent                   0.00
# loan_grade                    0.00
# loan_amnt                     0.00
# loan_int_rate                 9.55
# loan_status                   0.00
# loan_percent_income           0.00
# cb_person_default_on_file     0.00
# cb_person_cred_hist_length    0.00
# dtype: float64

# %%
print("NUMBER-OF-DATA =",df.shape[0])
print("AFTER DROPING ALL NULL-VALUES =",df.dropna().shape[0])
# Out:
# NUMBER-OF-DATA = 32416
# AFTER DROPING ALL NULL-VALUES = 28501

# %%
# HOW MUCH DATA WE LOST
total_number_of_data = 32416
after_drop = 28501

calculate = (total_number_of_data - after_drop) / total_number_of_data
print("We Lost {:.2f} Percentage Data When We Drop Null-Values".format(calculate))
# Out:
# We Lost 0.12 Percentage Data When We Drop Null-Values

# %%
df['person_age'].unique()
# Out:
# array([ 22,  21,  25,  23,  24,  26, 144, 123,  20,  32,  34,  29,  33,
#         28,  35,  31,  27,  30,  36,  40,  50,  45,  37,  39,  44,  43,
#         41,  46,  38,  47,  42,  48,  49,  58,  65,  51,  53,  66,  61,
#         54,  57,  59,  62,  60,  55,  52,  64,  70,  78,  69,  56,  73,
#         63,  94,  80,  84,  76,  67])

# %% [markdown]
# # Observation:
#
# - Outlier in person_age [144 , 123]

# %%
df['person_emp_length'].unique()
# Out:
# array([123.,   5.,   1.,   4.,   8.,   2.,   6.,   7.,   0.,   9.,   3.,
#         10.,  nan,  11.,  18.,  12.,  17.,  14.,  16.,  13.,  19.,  15.,
#         20.,  22.,  21.,  24.,  23.,  26.,  25.,  27.,  28.,  31.,  41.,
#         34.,  29.,  38.,  30.])

# %% [markdown]
# # Observation :
#
# - Outlier in person_emp_length

# %%
df = df.loc[df['person_age'] < 80]
df['person_age'].unique()
# Out:
# array([22, 21, 25, 23, 24, 26, 20, 32, 34, 29, 33, 28, 35, 31, 27, 30, 36,
#        40, 50, 45, 37, 39, 44, 43, 41, 46, 38, 47, 42, 48, 49, 58, 65, 51,
#        53, 66, 61, 54, 57, 59, 62, 60, 55, 52, 64, 70, 78, 69, 56, 73, 63,
#        76, 67])

# %%
df.shape
# Out:
# (32408, 12)

# %% [markdown]
# # WE ASSUME THAT 80 + AGE PERSON NOT TAKE LOAN SO WE REMOVE THEM.

# %%
df.query("person_age<=person_emp_length+14")
# Out:
#      person_age  person_income person_home_ownership  person_emp_length  \
# 0            22          59000                  RENT              123.0
# 210          21         192000              MORTGAGE              123.0
#
#     loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0      PERSONAL          D      35000          16.02            1
# 210     VENTURE          A      20000           6.54            0
#
#      loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                   0.59                         Y                           3
# 210                 0.10                         N                           4

# %%
df = df.loc[(df['person_emp_length'] < 66) | (df['person_emp_length'].isna()) , :]
df.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              887
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3093
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %% [markdown]
# - WE DO NOT REMOVE OUTLIER IN PERSON_EMO_LENGTH THAT WHY WE USE | (df['person_emp_length'].isna()) .
# - REMOVE DATA THAT IS NOT IMPORTANT

# %%
df.shape
# Out:
# (32406, 12)

# %%
df.drop('loan_percent_income',axis=1,inplace=True)
df.shape
# Out:
# (32406, 11)

# %% [markdown]
# # REMOVE OUTLIER THROUGH IQR METHOD

# %%
Q1 = df['person_age'].quantile(0.25)
Q3 = df['person_age'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_filtered = df[(df["person_age"] >= lower_bound) & (df["person_age"] <= upper_bound)]

# %%
print("BEFORE IQR METHOD :",df['person_age'].nunique())
print("AFTER IQR METHOD :",df_filtered['person_age'].nunique())
# Out:
# BEFORE IQR METHOD : 53
# AFTER IQR METHOD : 21

# %% [markdown]
# # FOR COLUMNS THAT HAVE OUTLIER

# %%
columns = [col for col in df.columns if df[col].dtype != '0']
columns = ['person_age',
 'person_income',
 'person_emp_length',
 'loan_amnt',
 'loan_int_rate',
 'cb_person_cred_hist_length']

# %%
Q1 = df[columns].quantile(0.25)
Q3 = df[columns].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

for column in columns:
    df = df[(df[column] >= lower_bound[column]) & (df[column] <= upper_bound[column])]

# %%
df.shape
# Out:
# (24003, 11)

# %%
df.head()
# Out:
#     person_age  person_income person_home_ownership  person_emp_length  \
# 1           21           9600                   OWN                5.0
# 2           25           9600              MORTGAGE                1.0
# 5           21           9900                   OWN                2.0
# 9           21          10000                   OWN                6.0
# 11          21          10000                   OWN                2.0
#
#         loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1         EDUCATION          B       1000          11.14            0
# 2           MEDICAL          C       5500          12.87            1
# 5           VENTURE          A       2500           7.14            1
# 9           VENTURE          D       1600          14.74            1
# 11  HOMEIMPROVEMENT          A       4500           8.63            1
#
#    cb_person_default_on_file  cb_person_cred_hist_length
# 1                          N                           2
# 2                          N                           3
# 5                          N                           2
# 9                          N                           3
# 11                         N                           2

# %%
# from ydata_profiling import ProfileReport

#profile = ProfileReport(df , title='updated_df' ,explorative=True)
#profile.to_file('updated_out_put.html')

# %%
df.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_status                   0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
numerical_columns = [col for col in df.columns if df[col].dtype != 'O']
categoricl_column = [col for col in df.columns if df[col].dtype == 'O']

# %%
categoricl_column
# Out:
# ['person_home_ownership',
#  'loan_intent',
#  'loan_grade',
#  'cb_person_default_on_file']

# %%
# remove loan_status
numerical_columns = ['person_age',
 'person_income',
 'person_emp_length',
 'loan_amnt',
 'loan_int_rate',
 'cb_person_cred_hist_length']

# %%
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numerical_columns),
        ('cat', categorical_transformer, categoricl_column)
    ])

# %%
x = df.drop('loan_status',axis=1)
y = df['loan_status']

X , X_test , Y , Y_TEST = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
X = preprocessor.fit_transform(X)
X_test = preprocessor.transform(X_test)

# %% [markdown]
# # ML Classification Models

# %%
model_list = {
    "LogisticRegression" : LogisticRegression(),
    "SVC" : SVC(),
    "XGBClassifier" : XGBClassifier(),
    "CatBoostClassifier" : CatBoostClassifier()
}

# %%
for name , model in model_list.items():

    model = model.fit(X,Y)
    y_pred = model.predict(X_test)

    print('MODEL NAME :',name)
    print('MODEL ACCURACY :')
    print(accuracy_score(Y_TEST,y_pred))

    print("*"*55)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# MODEL NAME : LogisticRegression
# MODEL ACCURACY :
# 0.8516975630077067
# *******************************************************
# MODEL NAME : SVC
# MODEL ACCURACY :
# 0.9073109768798167
# *******************************************************
# MODEL NAME : XGBClassifier
# MODEL ACCURACY :
# 0.9300145802957717
# *******************************************************
# Learning rate set to 0.036385
# 0:	learn: 0.6663998	total: 53.9ms	remaining: 53.8s
# 1:	learn: 0.6387821	total: 60.2ms	remaining: 30s
# 2:	learn: 0.6120906	total: 65.9ms	remaining: 21.9s
# 3:	learn: 0.5885885	total: 71.6ms	remaining: 17.8s
# 4:	learn: 0.5676565	total: 77.2ms	remaining: 15.4s
# 149:	learn: 0.2415640	total: 997ms	remaining: 5.65s
# 150:	learn: 0.2414253	total: 1s	remaining: 5.63s
# 151:	learn: 0.2412301	total: 1.01s	remaining: 5.63s
# 152:	learn: 0.2408566	total: 1.01s	remaining: 5.62s
# 153:	learn: 0.2407234	total: 1.02s	remaining: 5.6s
# 154:	learn: 0.2403397	total: 1.03s	remaining: 5.61s
# 155:	learn: 0.2402114	total: 1.03s	remaining: 5.6s
# 156:	learn: 0.2400843	total: 1.04s	remaining: 5.59s
# 157:	learn: 0.2399657	total: 1.05s	remaining: 5.58s
# 158:	learn: 0.2394764	total: 1.05s	remaining: 5.56s
# 159:	learn: 0.2391323	total: 1.06s	remaining: 5.55s
# 160:	learn: 0.2390013	total: 1.06s	remaining: 5.54s
# 161:	learn: 0.2384576	total: 1.07s	remaining: 5.54s
# 162:	learn: 0.2382755	total: 1.08s	remaining: 5.55s
# 163:	learn: 0.2381048	total: 1.09s	remaining: 5.54s
# 164:	learn: 0.2378047	total: 1.09s	remaining: 5.53s
# 165:	learn: 0.2373479	total: 1.1s	remaining: 5.52s
# 166:	learn: 0.2370999	total: 1.1s	remaining: 5.51s
# 167:	learn: 0.2369192	total: 1.11s	remaining: 5.5s
# 168:	learn: 0.2367122	total: 1.12s	remaining: 5.49s
# 169:	learn: 0.2365988	total: 1.12s	remaining: 5.48s
# 170:	learn: 0.2363816	total: 1.13s	remaining: 5.47s
# 171:	learn: 0.2363029	total: 1.13s	remaining: 5.46s
# 172:	learn: 0.2359935	total: 1.14s	remaining: 5.45s
# 173:	learn: 0.2358776	total: 1.15s	remaining: 5.44s
# 174:	learn: 0.2357315	total: 1.15s	remaining: 5.43s
# 175:	learn: 0.2356266	total: 1.16s	remaining: 5.42s
# 176:	learn: 0.2354399	total: 1.16s	remaining: 5.41s
# 177:	learn: 0.2350725	total: 1.17s	remaining: 5.4s
# 178:	learn: 0.2347472	total: 1.18s	remaining: 5.39s
# 179:	learn: 0.2341039	total: 1.18s	remaining: 5.38s
# 180:	learn: 0.2338256	total: 1.19s	remaining: 5.37s
# 181:	learn: 0.2336723	total: 1.19s	remaining: 5.37s
# 182:	learn: 0.2333837	total: 1.2s	remaining: 5.36s
# 183:	learn: 0.2333093	total: 1.21s	remaining: 5.35s
# 184:	learn: 0.2331396	total: 1.21s	remaining: 5.34s
# 185:	learn: 0.2330115	total: 1.22s	remaining: 5.33s
# 186:	learn: 0.2328731	total: 1.22s	remaining: 5.32s
# 187:	learn: 0.2326812	total: 1.23s	remaining: 5.31s
# 188:	learn: 0.2324154	total: 1.24s	remaining: 5.3s
# 189:	learn: 0.2321557	total: 1.24s	remaining: 5.29s
# 190:	learn: 0.2320107	total: 1.25s	remaining: 5.28s
# 191:	learn: 0.2318603	total: 1.25s	remaining: 5.28s
# 192:	learn: 0.2316998	total: 1.26s	remaining: 5.27s
# 193:	learn: 0.2313942	total: 1.26s	remaining: 5.26s
# 194:	learn: 0.2312105	total: 1.27s	remaining: 5.25s
# 799:	learn: 0.1670817	total: 5.05s	remaining: 1.26s
# 800:	learn: 0.1669942	total: 5.06s	remaining: 1.26s
# 801:	learn: 0.1669533	total: 5.07s	remaining: 1.25s
# 802:	learn: 0.1668905	total: 5.07s	remaining: 1.24s
# 803:	learn: 0.1668500	total: 5.08s	remaining: 1.24s
# 804:	learn: 0.1667996	total: 5.08s	remaining: 1.23s
# 805:	learn: 0.1667496	total: 5.09s	remaining: 1.22s
# 806:	learn: 0.1666906	total: 5.09s	remaining: 1.22s
# 807:	learn: 0.1666563	total: 5.11s	remaining: 1.21s
# 808:	learn: 0.1665880	total: 5.11s	remaining: 1.21s
# 809:	learn: 0.1665265	total: 5.12s	remaining: 1.2s
# 810:	learn: 0.1664575	total: 5.12s	remaining: 1.19s
# 811:	learn: 0.1664148	total: 5.13s	remaining: 1.19s
# 812:	learn: 0.1663467	total: 5.14s	remaining: 1.18s
# 813:	learn: 0.1662864	total: 5.14s	remaining: 1.18s
# 814:	learn: 0.1661887	total: 5.15s	remaining: 1.17s
# 815:	learn: 0.1661275	total: 5.16s	remaining: 1.16s
# 816:	learn: 0.1660472	total: 5.16s	remaining: 1.16s
# 817:	learn: 0.1659939	total: 5.17s	remaining: 1.15s
# 818:	learn: 0.1659420	total: 5.17s	remaining: 1.14s
# 819:	learn: 0.1659102	total: 5.18s	remaining: 1.14s
# 820:	learn: 0.1658551	total: 5.18s	remaining: 1.13s
# 821:	learn: 0.1658073	total: 5.19s	remaining: 1.12s
# 822:	learn: 0.1657588	total: 5.2s	remaining: 1.12s
# 823:	learn: 0.1657311	total: 5.2s	remaining: 1.11s
# 824:	learn: 0.1656968	total: 5.21s	remaining: 1.1s
# 825:	learn: 0.1656127	total: 5.21s	remaining: 1.1s
# 826:	learn: 0.1655237	total: 5.22s	remaining: 1.09s
# 827:	learn: 0.1654461	total: 5.22s	remaining: 1.08s
# 828:	learn: 0.1652615	total: 5.23s	remaining: 1.08s
# 829:	learn: 0.1652071	total: 5.24s	remaining: 1.07s
# 830:	learn: 0.1651051	total: 5.24s	remaining: 1.07s
# 831:	learn: 0.1650605	total: 5.25s	remaining: 1.06s
# 832:	learn: 0.1650110	total: 5.25s	remaining: 1.05s
# 833:	learn: 0.1649573	total: 5.26s	remaining: 1.05s
# 834:	learn: 0.1649069	total: 5.26s	remaining: 1.04s
# 835:	learn: 0.1648659	total: 5.27s	remaining: 1.03s
# 836:	learn: 0.1648390	total: 5.28s	remaining: 1.03s
# 837:	learn: 0.1648236	total: 5.28s	remaining: 1.02s
# 838:	learn: 0.1647688	total: 5.29s	remaining: 1.01s
# 839:	learn: 0.1647116	total: 5.29s	remaining: 1.01s
# 840:	learn: 0.1646801	total: 5.3s	remaining: 1s
# 841:	learn: 0.1646530	total: 5.3s	remaining: 995ms
# 842:	learn: 0.1645341	total: 5.31s	remaining: 989ms
# 843:	learn: 0.1645033	total: 5.31s	remaining: 982ms
# 844:	learn: 0.1643181	total: 5.32s	remaining: 976ms
# 845:	learn: 0.1642593	total: 5.33s	remaining: 970ms
# 989:	learn: 0.1566353	total: 6.22s	remaining: 62.8ms
# 990:	learn: 0.1565916	total: 6.23s	remaining: 56.5ms
# 991:	learn: 0.1565678	total: 6.23s	remaining: 50.3ms
# 992:	learn: 0.1565442	total: 6.24s	remaining: 44ms
# 993:	learn: 0.1564729	total: 6.25s	remaining: 37.7ms
# 994:	learn: 0.1564663	total: 6.25s	remaining: 31.4ms
# 995:	learn: 0.1563796	total: 6.26s	remaining: 25.1ms
# 996:	learn: 0.1563393	total: 6.26s	remaining: 18.8ms
# 997:	learn: 0.1562985	total: 6.27s	remaining: 12.6ms
# 998:	learn: 0.1562589	total: 6.28s	remaining: 6.28ms
# 999:	learn: 0.1562222	total: 6.28s	remaining: 0us
# MODEL NAME : CatBoostClassifier
# MODEL ACCURACY :
# 0.9254322016246616
# *******************************************************

# %%
model = model_list['XGBClassifier']

# %%
model_XGB = XGBClassifier()

param_grid = {
    'learning_rate': [0.1, 0.01, 0.001],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200, 300],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0]
}

cv = StratifiedKFold(n_splits=5 , shuffle=True , random_state=42)
serch = RandomizedSearchCV(estimator=model_XGB , param_distributions=param_grid, cv=cv ,  scoring='f1' , random_state=42 , n_iter=50)

# %%
serch.fit(X,Y)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importan...
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            random_state=None, ...),
#                    n_iter=50,
#                    param_distributions={'colsample_bytree': [0.8, 0.9, 1.0],
#                                         'learning_rate': [0.1, 0.01, 0.001],
#                                         'max_depth': [3, 5, 7],
#                                         'n_estimators': [100, 200, 300],
#                                         'subsample': [0.8, 0.9, 1.0]},
#                    random_state=42, scoring='f1')

# %%
serch.best_params_
# Out:
# {'subsample': 1.0,
#  'n_estimators': 200,
#  'max_depth': 7,
#  'learning_rate': 0.1,
#  'colsample_bytree': 1.0}

# %%
model = serch.best_estimator_
model.fit(X,Y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
prediction = model.predict(X_test)
score = accuracy_score(Y_TEST,prediction) * 100
print('SCORE :',score)
# Out:
# SCORE : 92.77233909602167

# %%
f1 = f1_score(Y_TEST,prediction)
print('F1-SCORE :',f1)
# Out:
# F1-SCORE : 0.8133405056481979

# %%
confusion_matrix(Y_TEST,prediction)
# Out:
# array([[3698,   37],
#        [ 310,  756]])

# %%
pd.crosstab(index=Y_TEST,columns=prediction , rownames=['ACTUAL'] , colnames=['PREDICTED'])
# Out:
# PREDICTED     0    1
# ACTUAL
# 0          3703   32
# 1           308  758

# %% [markdown]
# # CONVERT IN TO REAL FORMAT FOR UNDERSTAND
#
# - TP = 758 FN = 308
# - FP = 32  TN = 3703

# %%
model_cat_boost = CatBoostClassifier()

param_grid_cat = {
    'learning_rate': [0.01, 0.05, 0.1],
    'depth': [4, 6, 8],
    'iterations': [100, 200, 300],
    'l2_leaf_reg': [1, 3, 5],
}

random_serch_cat_boost = RandomizedSearchCV(estimator=model_cat_boost , param_distributions=param_grid_cat ,
                                            cv = 5 , scoring='f1' , n_iter=50)

# %%
random_serch_cat_boost.fit(X,Y)

# %%
best_params = random_serch_cat_boost.best_params_
print("Best Hyperparameters:", best_params)

best_model = random_serch_cat_boost.best_estimator_
test_accuracy = best_model.score(X, Y)
print("Test Accuracy:", test_accuracy)
# Out:
# Best Hyperparameters: {'learning_rate': 0.1, 'l2_leaf_reg': 1, 'iterations': 200, 'depth': 6}
# Test Accuracy: 0.9403187168003333

# %%
cat_model = random_serch_cat_boost.best_estimator_
cat_model.fit(X,Y)

# %%
Y_PRED_cat = cat_model.predict(X_test)

accuracy = accuracy_score(Y_TEST,Y_PRED_cat)
f1 = f1_score(Y_TEST,Y_PRED_cat)
c_report = classification_report(Y_TEST,Y_PRED_cat)

print('ACCURACY :',accuracy)
print('F1-SCORE :',f1)
print('CLASSIFICATION-REPORT :')
print(c_report)
# Out:
# ACCURACY : 0.926890231201833
# F1-SCORE : 0.8097560975609757
# CLASSIFICATION-REPORT :
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      3735
#            1       0.96      0.70      0.81      1066
#
#     accuracy                           0.93      4801
#    macro avg       0.94      0.85      0.88      4801
# weighted avg       0.93      0.93      0.92      4801

# %%
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostClassifier
from scipy.stats import randint as sp_randint

# Define the hyperparameter search space
param_dist = {
    'depth': sp_randint(3, 10),  # Depth of the trees
    'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],  # Learning rate
    'l2_leaf_reg': sp_randint(1, 10),  # L2 regularization coefficient
    'iterations': sp_randint(100, 500),  # Number of boosting iterations
    'subsample': [0.5, 0.75, 1.0],  # Fraction of samples used for training each tree
}

cat_boost = CatBoostClassifier()

# Instantiate RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=cat_boost, param_distributions=param_dist, n_iter=50, cv=5, scoring='accuracy')

# %%
# Perform RandomizedSearchCV
random_search.fit(X, Y)

# %%
best_params = random_search.best_params_
print('Best-Hyperparameters :',best_params)
# Out:
# Best-Hyperparameters : {'depth': 5, 'iterations': 370, 'l2_leaf_reg': 8, 'learning_rate': 0.1, 'subsample': 0.5}

# %%
best_model_cat_boost = random_search.best_estimator_
best_model_cat_boost.fit(X,Y)

# %%
y_pred_cat_boost = best_model_cat_boost.predict(X_test)
acc = accuracy_score(Y_TEST,y_pred_cat_boost)
print('CAT-BOOST-ACCURACY :',acc * 100)
# Out:
# CAT-BOOST-ACCURACY : 92.85565507186003

# %%
Y_PRED_cat = best_model_cat_boost.predict(X_test)

accuracy = accuracy_score(Y_TEST,Y_PRED_cat)
f1 = f1_score(Y_TEST,Y_PRED_cat)
c_report = classification_report(Y_TEST,Y_PRED_cat)

print('ACCURACY :',accuracy)
print('F1-SCORE :',f1)
print('CLASSIFICATION-REPORT :')
print(c_report)
# Out:
# ACCURACY : 0.9285565507186003
# F1-SCORE : 0.8148947652455477
# CLASSIFICATION-REPORT :
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96      3735
#            1       0.96      0.71      0.81      1066
#
#     accuracy                           0.93      4801
#    macro avg       0.94      0.85      0.89      4801
# weighted avg       0.93      0.93      0.92      4801

# %%
X_train , X_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# UPDATE PIPELINE
# ADD MODEL IN PIPELINE

pipeline = Pipeline(steps=[
    ("preprocessor" , preprocessor),
    ("cat_boost" , best_model_cat_boost)
    ])

# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)

# Predict on the test data
y_pred = pipeline.predict(X_test)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

f1_score = f1_score(y_test,y_pred)
print('F1-SCORE :',f1_score)
# Out:
# Accuracy: 0.9285565507186003
# F1-SCORE : 0.8148947652455477

# %%
import joblib

joblib.dump(pipeline , "pipeline.joblib")
# Out:
# ['pipeline.joblib']
